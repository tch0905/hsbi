# %%
import csv
import os
import requests
import re

def download_pdf(url, filename):
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, 'wb') as f:
            f.write(response.content)
        print(f"PDF downloaded and saved as {filename}")
    else:
        print(f"Failed to download PDF from {url}")

def main(input_path, output_dir):
    with open(input_path, 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            for header, url in row.items():
                pattern = r'(\d*)\.HK'
                match = re.findall(pattern, url)
                if match:
                    ric_path = os.path.join(output_dir, match[0])
                    os.makedirs(ric_path, exist_ok=True)
                if header == 'SDI':
                    continue
                if header == "Financial report":
                    urls = url.split("\n")
                    for url in urls:
                        filename = os.path.basename(url)
                        file_path = os.path.join(ric_path, filename)
                        download_pdf(url, file_path)
                if url.startswith('http'):  # Check if the value is a URL
                    filename = os.path.basename(url)
                    file_path = os.path.join(ric_path, filename)
                    download_pdf(url, file_path)


if __name__ == "__main__":
    path = '../data_explorer/faf_documents.csv'
    output = '../src'
    main(path,output)
# Out:
# PDF downloaded and saved as ../src\1477\2024010302045.pdf
# PDF downloaded and saved as ../src\1477\2023092600881.pdf
# PDF downloaded and saved as ../src\1477\2023042501560.pdf
# PDF downloaded and saved as ../src\1477\2023042501560.pdf
# PDF downloaded and saved as ../src\0011\2024010201372.pdf
# PDF downloaded and saved as ../src\0011\2023080800244.pdf
# PDF downloaded and saved as ../src\0011\2023031000328.pdf
# PDF downloaded and saved as ../src\0011\2023031000328.pdf
# PDF downloaded and saved as ../src\0151\2024010400249.pdf
# PDF downloaded and saved as ../src\0151\2023121400684.pdf
# PDF downloaded and saved as ../src\0151\2023072000236.pdf
# PDF downloaded and saved as ../src\0151\2023072000236.pdf
# PDF downloaded and saved as ../src\0806\2024010200229.pdf
# PDF downloaded and saved as ../src\0806\2023082400834.pdf
# PDF downloaded and saved as ../src\0806\2023032900546.pdf
# PDF downloaded and saved as ../src\0806\2023032900546.pdf
# PDF downloaded and saved as ../src\0909\2024010300778.pdf
# PDF downloaded and saved as ../src\0909\2023091300309.pdf
# PDF downloaded and saved as ../src\0909\2023042402102.pdf
# PDF downloaded and saved as ../src\0909\2023042402102.pdf
# PDF downloaded and saved as ../src\0975\2024010401158.pdf
# PDF downloaded and saved as ../src\0975\2023092200446.pdf
# PDF downloaded and saved as ../src\0975\2023042602473.pdf
# PDF downloaded and saved as ../src\0975\2023042602473.pdf
# PDF downloaded and saved as ../src\1398\2024010202928.pdf
# PDF downloaded and saved as ../src\1398\2023092600287.pdf
# PDF downloaded and saved as ../src\1398\2023042600550.pdf
# PDF downloaded and saved as ../src\1398\2023042600550.pdf
# PDF downloaded and saved as ../src\1658\2024010400633.pdf
# PDF downloaded and saved as ../src\1658\2023091500019.pdf
# PDF downloaded and saved as ../src\1658\2023042500143.pdf
# PDF downloaded and saved as ../src\1658\2023042500143.pdf
# PDF downloaded and saved as ../src\1787\2024010201366.pdf
# PDF downloaded and saved as ../src\1787\2023092600291.pdf
# PDF downloaded and saved as ../src\1787\2023042601316.pdf
# PDF downloaded and saved as ../src\1787\2023042601316.pdf
# PDF downloaded and saved as ../src\3759\2024010400675.pdf
# PDF downloaded and saved as ../src\3759\2023092500307.pdf
# PDF downloaded and saved as ../src\3759\2023042803359.pdf
# PDF downloaded and saved as ../src\3759\2023042803359.pdf
# PDF downloaded and saved as ../src\3969\2024010500843.pdf
# PDF downloaded and saved as ../src\3969\2023091400355.pdf
# PDF downloaded and saved as ../src\3969\2023042100325.pdf
# PDF downloaded and saved as ../src\3969\2023042100325.pdf
# PDF downloaded and saved as ../src\0002\2024010200723.pdf
# PDF downloaded and saved as ../src\0002\2023081100536.pdf
# PDF downloaded and saved as ../src\0002\2023031000520.pdf
# PDF downloaded and saved as ../src\0002\2023031000520.pdf
# PDF downloaded and saved as ../src\0038\2024010202588.pdf
# PDF downloaded and saved as ../src\0038\2023091800435.pdf
# PDF downloaded and saved as ../src\0038\2023042001393.pdf
# PDF downloaded and saved as ../src\0038\2023042001393.pdf
# PDF downloaded and saved as ../src\0069\2024010202555.pdf
# PDF downloaded and saved as ../src\0069\2023092100802.pdf
# PDF downloaded and saved as ../src\0069\2023042501489.pdf
# PDF downloaded and saved as ../src\0069\2023042501489.pdf
# PDF downloaded and saved as ../src\0136\2024010500511.pdf
# PDF downloaded and saved as ../src\0136\2023092200399.pdf
# PDF downloaded and saved as ../src\0136\2023041901145.pdf
# PDF downloaded and saved as ../src\0136\2023041901145.pdf
# PDF downloaded and saved as ../src\0271\2024010301521.pdf
# PDF downloaded and saved as ../src\0271\2023091400508.pdf
# PDF downloaded and saved as ../src\0271\2023041900457.pdf
# PDF downloaded and saved as ../src\0271\2023041900457.pdf
# PDF downloaded and saved as ../src\0933\2024010501364.pdf
# PDF downloaded and saved as ../src\0933\2023081800801.pdf
# PDF downloaded and saved as ../src\0933\2023062000028.pdf
# PDF downloaded and saved as ../src\0933\2023062000028.pdf
# PDF downloaded and saved as ../src\0981\2024010501206.pdf
# PDF downloaded and saved as ../src\0981\2023090500738.pdf
# PDF downloaded and saved as ../src\0981\2023042000809.pdf
# PDF downloaded and saved as ../src\0981\2023042000809.pdf
# PDF downloaded and saved as ../src\0990\2024010301131.pdf
# PDF downloaded and saved as ../src\0990\2023092201540.pdf
# PDF downloaded and saved as ../src\0990\2023042703669.pdf
# PDF downloaded and saved as ../src\0990\2023042703669.pdf
# PDF downloaded and saved as ../src\1055\2024010301123.pdf
# PDF downloaded and saved as ../src\1055\2023092000764.pdf
# PDF downloaded and saved as ../src\1055\2023042600538.pdf
# PDF downloaded and saved as ../src\1055\2023042600538.pdf
# PDF downloaded and saved as ../src\1182\2024010202627.pdf
# PDF downloaded and saved as ../src\1182\2023122100588.pdf
# PDF downloaded and saved as ../src\1182\2023072400586.pdf
# PDF downloaded and saved as ../src\1182\2023072400586.pdf
# PDF downloaded and saved as ../src\1310\2024010200757.pdf
# PDF downloaded and saved as ../src\1310\2023111500189.pdf
# PDF downloaded and saved as ../src\1310\2023111500189.pdf
# PDF downloaded and saved as ../src\1347\2024010400481.pdf
# PDF downloaded and saved as ../src\1347\2023090500019.pdf
# PDF downloaded and saved as ../src\1347\2023041100149.pdf
# PDF downloaded and saved as ../src\1347\2023041100149.pdf
# PDF downloaded and saved as ../src\1456\2024010500381.pdf
# PDF downloaded and saved as ../src\1456\2023090700760.pdf
# PDF downloaded and saved as ../src\1456\2023041200572.pdf
# PDF downloaded and saved as ../src\1456\2023041200572.pdf
# PDF downloaded and saved as ../src\1681\2023122902054.pdf
# PDF downloaded and saved as ../src\1681\2023092700025.pdf
# PDF downloaded and saved as ../src\1681\2023042800073.pdf
# PDF downloaded and saved as ../src\1681\2023042800073.pdf
# PDF downloaded and saved as ../src\1833\2024010201825.pdf
# PDF downloaded and saved as ../src\1833\2023090400057.pdf
# PDF downloaded and saved as ../src\1833\2023032200425.pdf
# PDF downloaded and saved as ../src\1833\2023032200425.pdf
# PDF downloaded and saved as ../src\1836\2024010500235.pdf
# PDF downloaded and saved as ../src\1836\2023083100771.pdf
# PDF downloaded and saved as ../src\1836\2023040302783.pdf
# PDF downloaded and saved as ../src\1836\2023040302783.pdf
# PDF downloaded and saved as ../src\1880\2024010201293.pdf
# PDF downloaded and saved as ../src\1880\2023083100671.pdf
# PDF downloaded and saved as ../src\1880\2023041900249.pdf
# PDF downloaded and saved as ../src\1880\2023041900249.pdf
# PDF downloaded and saved as ../src\1909\2024010301601.pdf
# PDF downloaded and saved as ../src\1909\2023083000381.pdf
# PDF downloaded and saved as ../src\1909\2023080900768.pdf
# PDF downloaded and saved as ../src\1909\2023080900768.pdf
# PDF downloaded and saved as ../src\1929\2024010301018.pdf
# PDF downloaded and saved as ../src\1929\2023113000081.pdf
# PDF downloaded and saved as ../src\1929\2023061500001.pdf
# PDF downloaded and saved as ../src\1929\2023061500001.pdf
# PDF downloaded and saved as ../src\1988\2024010203048.pdf
# PDF downloaded and saved as ../src\1988\2023092200528.pdf
# PDF downloaded and saved as ../src\1988\2023042101907.pdf
# PDF downloaded and saved as ../src\1988\2023042101907.pdf
# PDF downloaded and saved as ../src\2013\2024010201586.pdf
# PDF downloaded and saved as ../src\2013\2023091300534.pdf
# PDF downloaded and saved as ../src\2013\2023042801011.pdf
# PDF downloaded and saved as ../src\2013\2023042801011.pdf
# PDF downloaded and saved as ../src\2020\2024010202377.pdf
# PDF downloaded and saved as ../src\2020\2023083101196.pdf
# PDF downloaded and saved as ../src\2020\2023033001572.pdf
# PDF downloaded and saved as ../src\2020\2023033001572.pdf
# PDF downloaded and saved as ../src\2145\2024010400944.pdf
# PDF downloaded and saved as ../src\2145\2023092500344.pdf
# PDF downloaded and saved as ../src\2145\2023042601262.pdf
# PDF downloaded and saved as ../src\2145\2023042601262.pdf
# PDF downloaded and saved as ../src\2162\2024010203012.pdf
# PDF downloaded and saved as ../src\2162\2023091901016.pdf
# PDF downloaded and saved as ../src\2162\2023042400357.pdf
# PDF downloaded and saved as ../src\2162\2023042400357.pdf
# PDF downloaded and saved as ../src\2273\2024010400571.pdf
# PDF downloaded and saved as ../src\2273\2023092200416.pdf
# PDF downloaded and saved as ../src\2273\2023041900397.pdf
# PDF downloaded and saved as ../src\2273\2023041900397.pdf
# PDF downloaded and saved as ../src\2362\2024010401462.pdf
# PDF downloaded and saved as ../src\2362\2023092701154.pdf
# PDF downloaded and saved as ../src\2362\2023042803757.pdf
# PDF downloaded and saved as ../src\2362\2023042803757.pdf
# PDF downloaded and saved as ../src\2416\2024010401291.pdf
# PDF downloaded and saved as ../src\2416\2023092500317.pdf
# PDF downloaded and saved as ../src\2416\2023051500005.pdf
# PDF downloaded and saved as ../src\2416\2023051500005.pdf
# PDF downloaded and saved as ../src\2469\2024010400800.pdf
# PDF downloaded and saved as ../src\2469\2023092000412.pdf
# PDF downloaded and saved as ../src\2469\2023042501065.pdf
# PDF downloaded and saved as ../src\2469\2023042501065.pdf
# PDF downloaded and saved as ../src\3383\2024010202847.pdf
# PDF downloaded and saved as ../src\3383\2023091500282.pdf
# PDF downloaded and saved as ../src\3383\2023042100483.pdf
# PDF downloaded and saved as ../src\3383\2023042100483.pdf
# PDF downloaded and saved as ../src\3668\2024010400609.pdf
# PDF downloaded and saved as ../src\3668\2023091900331.pdf
# PDF downloaded and saved as ../src\3668\2023042600831.pdf
# PDF downloaded and saved as ../src\3668\2023042600831.pdf
# PDF downloaded and saved as ../src\3888\2024010301481.pdf
# PDF downloaded and saved as ../src\3888\2023092100993.pdf
# PDF downloaded and saved as ../src\3888\2023042601781.pdf
# PDF downloaded and saved as ../src\3888\2023042601781.pdf
# PDF downloaded and saved as ../src\3900\2024010501662.pdf
# PDF downloaded and saved as ../src\3900\2023092201088.pdf
# PDF downloaded and saved as ../src\3900\2023042704866.pdf
# PDF downloaded and saved as ../src\3900\2023042704866.pdf
# PDF downloaded and saved as ../src\3918\2024010200295.pdf
# PDF downloaded and saved as ../src\3918\2023082400640.pdf
# PDF downloaded and saved as ../src\3918\2023032300436.pdf
# PDF downloaded and saved as ../src\3918\2023032300436.pdf
# PDF downloaded and saved as ../src\3958\2024010300605.pdf
# PDF downloaded and saved as ../src\3958\2023092100270.pdf
# PDF downloaded and saved as ../src\3958\2023041700375.pdf
# PDF downloaded and saved as ../src\3958\2023041700375.pdf
# PDF downloaded and saved as ../src\6889\2024010400559.pdf
# PDF downloaded and saved as ../src\6889\2023120700367.pdf
# PDF downloaded and saved as ../src\6889\2023053100538.pdf
# PDF downloaded and saved as ../src\6889\2023053100538.pdf
# PDF downloaded and saved as ../src\9636\2024010200203.pdf
# PDF downloaded and saved as ../src\9636\2023092000045.pdf
# PDF downloaded and saved as ../src\9636\2023042600589.pdf
# PDF downloaded and saved as ../src\9636\2023042600589.pdf
# PDF downloaded and saved as ../src\9858\2024010201466.pdf
# PDF downloaded and saved as ../src\9858\2023091300315.pdf
# PDF downloaded and saved as ../src\9858\2023042401665.pdf
# PDF downloaded and saved as ../src\9858\2023042401665.pdf
# PDF downloaded and saved as ../src\9860\2024010400565.pdf
# PDF downloaded and saved as ../src\9860\2023092500299.pdf
# PDF downloaded and saved as ../src\9860\2023061900005.pdf
# PDF downloaded and saved as ../src\9860\2023061900005.pdf
# PDF downloaded and saved as ../src\9923\2024010500554.pdf
# PDF downloaded and saved as ../src\9923\2023092800741.pdf
# PDF downloaded and saved as ../src\9923\2023042601847.pdf
# PDF downloaded and saved as ../src\9923\2023042601847.pdf
# PDF downloaded and saved as ../src\9930\2024010201448.pdf
# PDF downloaded and saved as ../src\9930\2023090400063.pdf
# PDF downloaded and saved as ../src\9930\2023051200007.pdf
# PDF downloaded and saved as ../src\9930\2023051200007.pdf
